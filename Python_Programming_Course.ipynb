# %% [markdown]
# <a href="https://colab.research.google.com/github/umair594/InterneePK_60DaysChallenge/blob/main/Python_Programming_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Complete Python Programming Course**

# %% [markdown]
# **Language**: English & Urdu (Bilingual)
#
# **Purpose:** This course is designed as a complete, beginner-to-advanced Python learning resource. You can:
#
# Use it as a **personal project**
#
# Upload it to **GitHub**
#
# Share it on **social media platforms**
#
# Teach **students**, **friends**, and **beginners** who want to learn Python

# %% [markdown]
# # **How to Use This Course**

# %% [markdown]
# Each topic includes:
#
# Explanation in English
#
# Explanation in Urdu
#
# Python examples
#
# Learners should practice examples by running them.
#
# This course is suitable for self-study and teaching.

# %% [markdown]
# # **Table of Contents**

# %% [markdown]
# 1.Introduction to Python
#
# 2.Installing Python & Setup
#
# 3.Python Syntax & Variables
#
# 4.Data Types
#
# 5.Input & Output
#
# 6.Operators
#
# 7.Conditional Statements
#
# 8.Loops
#
# 9.Functions
#
# 10.Lists
#
# 11.Tuples
#
# 12.Sets
#
# 13.Dictionaries
#
# 14.Strings (Advanced)
#
# 15.File Handling
#
# 16.Error & Exception Handling
#
# 17.Object-Oriented Programming (OOP)
#
# 18.Modules & Packages
#
# 19.Virtual Environments & pip
#
# 20.Working with Date & Time
#
# 21.Regular Expressions
#
# 22.Introduction to Libraries (NumPy, Pandas, Matplotlib)
#
# 23.Mini Projects
#
# 24.Final Project Ideas
#
# 25.GitHub & Sharing Guide

# %% [markdown]
# # **1. Introduction to Python**

# %% [markdown]
# **English Explanation**
#
# Python is a high-level, interpreted programming language created by Guido van Rossum. It is easy to learn, readable, and widely used in:
#
# **Web Development**
#
# **Data Science**
#
# **Machine Learning**
#
# **Automation**
#
# **Desktop Applications**

# %% [markdown]
# **Urdu Explanation**
#
# Python aik high-level programming language hai jo Guido van Rossum ne banayi. Yeh seekhne mein asaan hai aur zyada tar istemal hoti hai:
#
# **Web Development**
#
# **Data Science**
#
# **Machine Learning**
#
# **Automation**
#
# **Software Development**

# %% [markdown]
# # **First Python Program**

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# # **2. Installing Python & Setup**

# %% [markdown]
# **English**
#
# Download Python from https://www.python.org
#
# Install Python and check Add Python to PATH
#
# Use any editor: VS Code, PyCharm, or Notepad++
#
# **Urdu**
#
# Python download karein python.org se
#
# Install karte waqt Add Python to PATH select karein
#
# VS Code ya PyCharm jaise editor use karein

# %% [markdown]
# # **3. Python Syntax & Variables**

# %% [markdown]
# **English**
#
# Variables store data values.

# %%
name = "Ali"
age = 20
print(name, age)
# Out:
# Ali 20

# %% [markdown]
# **Urdu**
#
# Variables data ko store karte hain.

# %%
name = "Ali"
age = 20
print(name, age)
# Out:
# Ali 20

# %% [markdown]
# # **4. Data Types**

# %% [markdown]
# **English**
#
# Common Python data types:
#
# int
#
# float
#
# str
#
# bool

# %%
x = 10 # int
y = 10.5 # float
name = "Python" # string
is_active = True # boolean

# %% [markdown]
# **Urdu**
#
# Python mein mukhtalif data types hotay hain:
#
# int (number)
#
# float (decimal)
#
# str (text)
#
# bool (True/False)

# %% [markdown]
# # **5. Input & Output**

# %% [markdown]
# **English**

# %%
name = input("Enter your name: ")
print("Welcome", name)
# Out:
# Enter your name: Umair
# Welcome Umair

# %% [markdown]
# **Urdu**

# %%
name = input("Apna naam likhein: ")
print("Khush aamdeed", name)
# Out:
# Apna naam likhein: Umair
# Khush aamdeed Umair

# %% [markdown]
# # **6. Operators**

# %% [markdown]
# **English**
#
# Arithmetic Operators: +, -, *, /, %
#
# Addition
# Substraction
# Multiplication
# Division
# Percentage

# %%
a = 10
b = 3
print(a + b)
print(a % b)
# Out:
# 13
# 1

# %% [markdown]
# **Urdu**
#
# Operators calculations ke liye use hotay hain.

# %% [markdown]
# # **7. Conditional Statements**

# %% [markdown]
# **English**

# %%
age = 18
if age >= 18:
    print("You are eligible")
else:
    print("Not eligible")
# Out:
# You are eligible

# %% [markdown]
# **Urdu**
#
# Condition ke zariye decision liya jata hai.

# %% [markdown]
# # **8. Loops**

# %% [markdown]
# **English**

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# **Urdu**
#
# Loops aik kaam ko bar bar repeat karte hain.

# %% [markdown]
# # **9. Functions**

# %% [markdown]
# **English**

# %%
def greet(name):
  return "Hello " + name


print(greet("Ali"))
# Out:
# Hello Ali

# %% [markdown]
# **Urdu**
#
# Functions code ko reuse karne ke liye hotay hain.

# %% [markdown]
# # **10. Lists**

# %%
fruits = ["apple", "banana", "mango"]
print(fruits[0])
# Out:
# apple

# %% [markdown]
# # **11. Tuples**

# %%
colors = ("red", "green", "blue")

# %% [markdown]
# # **12. Sets**

# %%
numbers = {1, 2, 3, 3}
print(numbers)
# Out:
# {1, 2, 3}

# %% [markdown]
# # **13. Dictionaries**

# %%
student = {
"name": "Ali",
"age": 20
}
print(student["name"])
# Out:
# Ali

# %% [markdown]
# # **14. File Handling**

# %%
file = open("data.txt", "w")
file.write("Hello Python")
file.close()

# %% [markdown]
# # **15. Exception Handling**

# %%
try:
    x = int(input("Enter number: "))
except ValueError:
    print("Invalid input")
# Out:
# Enter number: 25

# %% [markdown]
# # **16. Object-Oriented Programming (OOP)**

# %%
class Student:
    def __init__(self, name):
        self.name = name

    def show(self):
        print(self.name)

s1 = Student("Ali")
s1.show()
# Out:
# Ali

# %% [markdown]
# # **17. Mini Projects**

# %% [markdown]
# **Number Guessing Game**

# %% [markdown]
# **Project Description**
#
# The computer generates a random number between 1 and 100.
# The player keeps guessing the number.
# After each guess, the program tells whether the guess is Too High or Too Low.
# The game ends when the correct number is guessed.

# %%
import random

def number_guessing_game():
    print("Welcome to the Number Guessing Game!")
    print("I have selected a number between 1 and 100. Can you guess it?")

    # Generate a random number between 1 and 100
    secret_number = random.randint(1, 100)
    attempts = 0

    while True:
        try:
            guess = int(input("Enter your guess: "))
            attempts += 1

            if guess < secret_number:
                print("Too low! Try again.")
            elif guess > secret_number:
                print("Too high! Try again.")
            else:
                print(f"Congratulations! You guessed the number {secret_number} in {attempts} attempts.")
                break
        except ValueError:
            print("Invalid input! Please enter an integer.")

# Run the game
number_guessing_game()

# %% [markdown]
# **Calculator App**

# %% [markdown]
# **Project Description**
#
# This is a simple calculator application that performs basic arithmetic operations:
#
# Addition
#
# Subtraction
#
# Multiplication
#
# Division
#
# The user selects an operation, enters two numbers, and the program displays the result.

# %%
# Simple Calculator in Python

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Error: Division by zero"

def calculator():
    print("Welcome to the Python Calculator!")
    print("Select an operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")

    choice = input("Enter your choice (1-4): ")

    if choice in ["1", "2", "3", "4"]:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == "1":
            print("Result:", add(num1, num2))
        elif choice == "2":
            print("Result:", subtract(num1, num2))
        elif choice == "3":
            print("Result:", multiply(num1, num2))
        elif choice == "4":
            print("Result:", divide(num1, num2))
    else:
        print("Invalid choice! Please select 1-4.")

# Run the calculator
calculator()

# %% [markdown]
# **Student Management System**

# %% [markdown]
# **Project Description**
#
# The Student Management System allows users to:
#
# Add new students
#
# View all students
#
# Search for a student
#
# Update student information
#
# Delete a student
#
# This project helps learners understand:
#
# Lists and dictionaries
#
# Functions
#
# Loops
#
# Conditional logic
#
# Real-world program structure
#
# Features
#
# Menu-based interface
#
# Stores student records in memory
#
# Each student has:
#
# ID
#
# Name
#
# Age
#
# Course

# %%
students = []

def add_student():
    student_id = input("Enter student ID: ")
    name = input("Enter student name: ")
    age = input("Enter student age: ")
    course = input("Enter student course: ")

    student = {
        "id": student_id,
        "name": name,
        "age": age,
        "course": course
    }

    students.append(student)
    print("Student added successfully.")

def view_students():
    if not students:
        print("No student records found.")
        return

    print("\nStudent List:")
    for student in students:
        print(
            f"ID: {student['id']}, "
            f"Name: {student['name']}, "
            f"Age: {student['age']}, "
            f"Course: {student['course']}"
        )

def search_student():
    student_id = input("Enter student ID to search: ")
    for student in students:
        if student["id"] == student_id:
            print("Student Found:")
            print(student)
            return
    print("Student not found.")

def update_student():
    student_id = input("Enter student ID to update: ")
    for student in students:
        if student["id"] == student_id:
            student["name"] = input("Enter new name: ")
            student["age"] = input("Enter new age: ")
            student["course"] = input("Enter new course: ")
            print("Student record updated.")
            return
    print("Student not found.")

def delete_student():
    student_id = input("Enter student ID to delete: ")
    for student in students:
        if student["id"] == student_id:
            students.remove(student)
            print("Student deleted.")
            return
    print("Student not found.")

def menu():
    while True:
        print("\nStudent Management System")
        print("1. Add Student")
        print("2. View Students")
        print("3. Search Student")
        print("4. Update Student")
        print("5. Delete Student")
        print("6. Exit")

        choice = input("Enter your choice (1-6): ")

        if choice == "1":
            add_student()
        elif choice == "2":
            view_students()
        elif choice == "3":
            search_student()
        elif choice == "4":
            update_student()
        elif choice == "5":
            delete_student()
        elif choice == "6":
            print("Exiting program.")
            break
        else:
            print("Invalid choice. Try again.")

menu()

# %% [markdown]
# **To-Do List**

# %% [markdown]
# **Project Description**
#
# The To-Do List application helps users manage daily tasks.
# Users can:
#
# Add tasks
#
# View tasks
#
# Mark tasks as completed
#
# Delete tasks
#
# Exit the application
#
# This project teaches:
#
# Lists and dictionaries
#
# Functions
#
# Loops
#
# Conditional statements
#
# Simple task management logic
#
# **Features**
#
# Menu-driven interface
#
# Task status (Pending / Completed)
#
# Easy to extend with file handling or GUI

# %% [markdown]
# # **18. Final Project Ideas**

# %% [markdown]
# **Python Quiz App**

# %% [markdown]
# **Project Description**
#
# The Quiz App asks multiple-choice questions, checks the user’s answers, and calculates the final score at the end of the quiz.
#
# This project helps learners understand:
#
# Lists and dictionaries
#
# Loops
#
# Conditional statements
#
# Functions
#
# Basic scoring logic
#
# **Features**
#
# Multiple-choice questions
#
# Automatic score calculation
#
# Final result display
#
# Easy to add more questions

# %%
questions = [
    {
        "question": "What is the output of print(2 + 3)?",
        "options": ["A. 23", "B. 5", "C. 2+3", "D. Error"],
        "answer": "B"
    },
    {
        "question": "Which keyword is used to define a function in Python?",
        "options": ["A. func", "B. define", "C. def", "D. function"],
        "answer": "C"
    },
    {
        "question": "Which data type is used to store text in Python?",
        "options": ["A. int", "B. float", "C. str", "D. bool"],
        "answer": "C"
    },
    {
        "question": "Which symbol is used for comments in Python?",
        "options": ["A. //", "B. <!-- -->", "C. #", "D. **"],
        "answer": "C"
    }
]

def start_quiz():
    score = 0

    print("Welcome to the Python Quiz App")
    print("Select the correct option (A, B, C, or D)\n")

    for index, q in enumerate(questions, start=1):
        print(f"Q{index}: {q['question']}")
        for option in q["options"]:
            print(option)

        user_answer = input("Your answer: ").upper()

        if user_answer == q["answer"]:
            print("Correct!\n")
            score += 1
        else:
            print(f"Wrong! Correct answer is {q['answer']}\n")

    print("Quiz Completed!")
    print(f"Your Score: {score} out of {len(questions)}")

    percentage = (score / len(questions)) * 100
    print(f"Percentage: {percentage}%")

start_quiz()

# %% [markdown]
# **Expense Tracker**

# %% [markdown]
# **Project Description**
#
# The Expense Tracker allows users to:
#
# Add income and expense entries
#
# View all transactions
#
# Check current balance
#
# Delete an entry
#
# Exit the program
#
# It teaches:
#
# Lists and dictionaries
#
# Functions
#
# Loops
#
# Conditional statements
#
# Basic financial management logic

# %%
transactions = []

def add_transaction():
    t_type = input("Enter type (Income/Expense): ").capitalize()
    if t_type not in ["Income", "Expense"]:
        print("Invalid type! Use Income or Expense.")
        return
    amount = float(input("Enter amount: "))
    description = input("Enter description: ")

    transaction = {
        "type": t_type,
        "amount": amount,
        "description": description
    }

    transactions.append(transaction)
    print(f"{t_type} of {amount} added successfully!")

def view_transactions():
    if not transactions:
        print("No transactions recorded.")
        return

    print("\nAll Transactions:")
    for i, t in enumerate(transactions, start=1):
        print(f"{i}. {t['type']} - {t['amount']} - {t['description']}")

def calculate_balance():
    balance = 0
    for t in transactions:
        if t["type"] == "Income":
            balance += t["amount"]
        else:
            balance -= t["amount"]
    print(f"\nCurrent Balance: {balance}")

def delete_transaction():
    view_transactions()
    if not transactions:
        return
    t_num = int(input("Enter transaction number to delete: "))
    if 1 <= t_num <= len(transactions):
        removed = transactions.pop(t_num - 1)
        print(f"Removed transaction: {removed['type']} - {removed['amount']}")
    else:
        print("Invalid transaction number.")

def menu():
    while True:
        print("\nExpense Tracker Menu")
        print("1. Add Transaction")
        print("2. View Transactions")
        print("3. Calculate Balance")
        print("4. Delete Transaction")
        print("5. Exit")

        choice = input("Choose an option (1-5): ")

        if choice == "1":
            add_transaction()
        elif choice == "2":
            view_transactions()
        elif choice == "3":
            calculate_balance()
        elif choice == "4":
            delete_transaction()
        elif choice == "5":
            print("Exiting Expense Tracker. Goodbye!")
            break
        else:
            print("Invalid choice. Try again.")

menu()

# %% [markdown]
# **Weather App (API based)**

# %% [markdown]
# **Project Description**
#
# The Weather App allows users to:
#
# Enter a city name
#
# Fetch real-time weather data
#
# Display temperature, humidity, and weather description
#
# This project teaches:
#
# Working with APIs
#
# JSON data handling
#
# Functions and loops
#
# Error handling
#
# External libraries (requests)
#
# Prerequisites
#
# Python installed
#
# **Install requests library:**
#
# pip install requests
# Sign up for a free API key at OpenWeatherMap

# %%
import requests

def get_weather(city_name, api_key):
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        "q": city_name,
        "appid": api_key,
        "units": "metric"  # Celsius
    }

    try:
        response = requests.get(base_url, params=params)
        data = response.json()

        if response.status_code == 200:
            city = data["name"]
            country = data["sys"]["country"]
            temp = data["main"]["temp"]
            humidity = data["main"]["humidity"]
            description = data["weather"][0]["description"]

            print(f"\nWeather in {city}, {country}:")
            print(f"Temperature: {temp}°C")
            print(f"Humidity: {humidity}%")
            print(f"Condition: {description.title()}")
        else:
            print(f"City not found or error occurred. Message: {data['message']}")
    except Exception as e:
        print("An error occurred:", e)

def main():
    api_key = input("Enter your OpenWeatherMap API Key: ")
    while True:
        city = input("\nEnter city name (or 'exit' to quit): ")
        if city.lower() == "exit":
            print("Exiting Weather App.")
            break
        get_weather(city, api_key)

main()

# %% [markdown]
# **Automation Script**

# %% [markdown]
# **Project Description**
#
# This script automatically organizes files in a folder into subfolders based on their extensions.
#
# For example:
#
# .jpg, .png → Images
#
# .pdf, .docx → Documents
#
# .mp3, .wav → Music
#
# **This project teaches:**
#
# Working with files and folders
#
# Using os and shutil modules
#
# Loops and conditionals
#
# Simple automation tasks

# %%
import os
import shutil

# Change this path to the folder you want to organize
folder_path = input("Enter the folder path to organize: ")

# Create a dictionary to map file extensions to folder names
file_types = {
    "Images": [".jpg", ".jpeg", ".png", ".gif"],
    "Documents": [".pdf", ".docx", ".txt", ".xlsx"],
    "Music": [".mp3", ".wav"],
    "Videos": [".mp4", ".mov", ".avi"],
    "Archives": [".zip", ".rar", ".tar", ".gz"]
}

# Create folders if they don't exist
for folder in file_types.keys():
    folder_dir = os.path.join(folder_path, folder)
    if not os.path.exists(folder_dir):
        os.makedirs(folder_dir)

# Move files to appropriate folders
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)

    if os.path.isfile(file_path):
        moved = False
        for folder, extensions in file_types.items():
            if filename.lower().endswith(tuple(extensions)):
                shutil.move(file_path, os.path.join(folder_path, folder, filename))
                print(f"Moved {filename} to {folder}")
                moved = True
                break
        if not moved:
            # If extension not in dictionary, move to 'Others'
            others_dir = os.path.join(folder_path, "Others")
            if not os.path.exists(others_dir):
                os.makedirs(others_dir)
            shutil.move(file_path, os.path.join(others_dir, filename))
            print(f"Moved {filename} to Others")

print("\nFolder organized successfully!")

# %% [markdown]
# # **19. GitHub Upload Guide**

# %% [markdown]
# **English**
#
# Create a GitHub repository
#
# Add this course as README.md
#
# Upload example files
#
# Share repository link
#
# **Urdu**
#
# GitHub par repository banayein
#
# Course ko README.md mein daalein
#
# Files upload karein
#
# Link share karein

# %% [markdown]
# # **20. License & Sharing**

# %% [markdown]
# You may use this course for:
#
# Teaching
#
# Learning
#
# Sharing on social media
#
# Suggested License: **MIT** License

# %% [markdown]
# # **Final Note**

# %% [markdown]
# **English:** Keep practicing and teaching others.
#
# **Urdu:** Practice jari rakhein aur doosron ko sikhayein.

# %% [markdown]
# # ***Happy Python Coding!***
